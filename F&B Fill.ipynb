# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\himanshu bagoria\OneDrive\Desktop\loan dataset\loan dataset\Loan payments data.csv")

# %%
dataset.head(10)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 5  xqd20160706     PAIDOFF        300      7       9/9/2016  9/15/2016
# 6  xqd20160007     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 7  xqd20160008     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 8  xqd20160909     PAIDOFF       1000     30       9/9/2016  10/8/2016
# 9  xqd20160010     PAIDOFF        800     15      9/10/2016  9/24/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# ...

# %%
#dataset.fillna(10)

# %%
#bfilling =backwardfilling

# %%
dataset.fillna(method="bfill")
# Out:
# C:\Users\himanshu bagoria\AppData\Local\Temp\ipykernel_9796\193979722.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="bfill")
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# ...

# %%
#forwardfilling =

# %%
dataset.fillna(method="ffill")
# Out:
# C:\Users\himanshu bagoria\AppData\Local\Temp\ipykernel_9796\2748457647.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="ffill")
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# ...

# %%
dataset.fillna(method="bfill",axis=1)
# Out:
# C:\Users\himanshu bagoria\AppData\Local\Temp\ipykernel_9796\4120435336.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="bfill",axis=1)
#          Loan_ID         loan_status Principal terms effective_date  \
# 0    xqd20166231             PAIDOFF      1000    30       9/8/2016
# 1    xqd20168902             PAIDOFF      1000    30       9/8/2016
# 2    xqd20160003             PAIDOFF      1000    30       9/8/2016
# 3    xqd20160004             PAIDOFF      1000    15       9/8/2016
# 4    xqd20160005             PAIDOFF      1000    30       9/9/2016
# ..           ...                 ...       ...   ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF      1000    30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF      1000    15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF       800    15      9/12/2016
# ...

# %%
dataset.fillna(method="ffill",axis=1)
# Out:
# C:\Users\himanshu bagoria\AppData\Local\Temp\ipykernel_9796\629923051.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="ffill",axis=1)
#          Loan_ID         loan_status Principal terms effective_date  \
# 0    xqd20166231             PAIDOFF      1000    30       9/8/2016
# 1    xqd20168902             PAIDOFF      1000    30       9/8/2016
# 2    xqd20160003             PAIDOFF      1000    30       9/8/2016
# 3    xqd20160004             PAIDOFF      1000    15       9/8/2016
# 4    xqd20160005             PAIDOFF      1000    30       9/9/2016
# ..           ...                 ...       ...   ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF      1000    30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF      1000    15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF       800    15      9/12/2016
# ...
